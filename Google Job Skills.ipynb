# %%
# for some  basic operations
import numpy as np
import pandas as pd

# %%
# for visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# for providing path
import os

# %%
# reading the data

data = pd.read_csv('job_skills.csv')

# %%
data.head(3)
# Out:
#   Company                                              Title  \
# 0  Google                       Google Cloud Program Manager
# 1  Google  Supplier Development Engineer (SDE), Cable/Con...
# 2  Google  Data Analyst, Product and Tools Operations, Go...
#
#                        Category                     Location  \
# 0            Program Management                    Singapore
# 1  Manufacturing & Supply Chain              Shanghai, China
# 2           Technical Solutions  New York, NY, United States
#
#                                     Responsibilities  \
# 0  Shape, shepherd, ship, and show technical prog...
# 1  Drive cross-functional activities in the suppl...
# 2  Collect and analyze data to draw insight and i...
#
#                               Minimum Qualifications  \
# 0  BA/BS degree or equivalent practical experienc...
# 1  BS degree in an Engineering discipline or equi...
# 2  Bachelor’s degree in Business, Economics, Stat...
#
#                             Preferred Qualifications
# 0  Experience in the business technology market a...
# 1  BSEE, BSME or BSIE degree.\nExperience of usin...
# 2  Experience partnering or consulting cross-func...

# %%
data.shape
# Out:
# (1250, 7)

# %%
data.describe()
# Out:
#        Company                 Title                    Category  \
# count     1250                  1250                        1250
# unique       2                   794                          23
# top     Google  Business Intern 2018  Sales & Account Management
# freq      1227                    35                         168
#
#                                 Location  \
# count                               1250
# unique                                92
# top     Mountain View, CA, United States
# freq                                 190
#
#                                          Responsibilities  \
# count                                                1235
# unique                                                801
# top     Responsibilities and detailed projects will be...
# freq                                                   33
#
#                                    Minimum Qualifications  \
# count                                                1236
# unique                                                807
# top     Currently enrolled in a Bachelor's or Master's...
# freq                                                   32
#
#                                  Preferred Qualifications
# count                                                1236
# unique                                                821
# top     Interest in the technology industry and Google...
# freq                                                   32

# %%
# Checking the null
data.isnull().any()
# Out:
# Company                     False
# Title                       False
# Category                    False
# Location                    False
# Responsibilities             True
# Minimum Qualifications       True
# Preferred Qualifications     True
# dtype: bool

# %%
# The companies involved
plt.rcParams['figure.figsize'] = (7,9)
plt.style.use('_classic_test')

data['Company'].value_counts().plot.bar(color = 'cyan')
plt.title('The companies Involved for recruitment', fontsize = 20)
plt.xlabel('Names of companies', fontsize = 15)
plt.show()

# %%
# checking most popular top 20 types of job titles

plt.rcParams['figure.figsize'] = (19,8)

color = plt.cm.PuRd(np.linspace(0, 1, 20))
data['Title'].value_counts().sort_values(ascending = False).head(20).plot.bar(color = color)
plt.title('Most popular 20 Job title of Google', fontsize = 20)
plt.xlabel('Names pf Job Titles', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()

# %%
# checking most popular top 20 types of categories
 
plt.rcParams['figure.figsize'] = (19,8)

color = plt.cm.BuPu(np.linspace(0, 1, 20))
data['Category'].value_counts().sort_values(ascending = False).head(20).plot.bar(color = color)
plt.title('Most popular 20 job categories of Google', fontsize = 20)
plt.xlabel('Name of Job categories', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()

# %%
from wordcloud import WordCloud
from wordcloud import STOPWORDS

# %%
# checking most popular job destinations 



stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color = 'yellow',
                      width = 2000,
                      height = 2000).generate(str(data['Location']))

plt.rcParams['figure.figsize'] = (12, 12)
plt.axis('off')
plt.imshow(wordcloud)
plt.title('Location with Most Jobs', fontsize = 30)
plt.show()

# %%
# Checking the most popular Responsibilties

from wordcloud import WordCloud
from wordcloud import STOPWORDS

stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color = 'lightgreen', max_words = 100,
                      width = 2000,
                       height = 2000).generate(str(data['Responsibilities']))

plt.rcParams['figure.figsize'] = (12, 12)
plt.axis('off')
plt.imshow(wordcloud)
plt.title('Most Available Responsibilties', fontsize = 30)
plt.show()
